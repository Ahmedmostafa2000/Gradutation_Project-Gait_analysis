# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:\\Career\\GradProj\\New deal\\Dataset\\parkinson_data.csv')
df.drop('Unnamed: 0', axis = 1,inplace=True)

df.columns = ['Time',
 'AccV',
 'AccML',
 'AccAP',
 'StartHesitation',
 'Turn',
 'Walking',
 'idx',
 'ID',
 'len_df']

# %%
df['class'] = np.array(df['Walking'] | df['StartHesitation'] | df['Turn'],dtype = int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7062672 entries, 0 to 7062671
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Time             int64
#  1   AccV             float64
#  2   AccML            float64
#  3   AccAP            float64
#  4   StartHesitation  int64
#  5   Turn             int64
#  6   Walking          int64
#  7   idx              int64
#  8   ID               object
#  9   len_df           int64
#  10  class            int32
# dtypes: float64(3), int32(1), int64(6), object(1)
# memory usage: 565.8+ MB

# %%
df.head()
# Out:
#    Time      AccV     AccML     AccAP  StartHesitation  Turn  Walking  idx  \
# 0     0 -9.665890  0.042550  0.184744                0     0        0    0
# 1     1 -9.672969  0.049217  0.184644                0     0        0    0
# 2     2 -9.670260  0.033620  0.193790                0     0        0    0
# 3     3 -9.673356  0.035159  0.184369                0     0        0    0
# 4     4 -9.671458  0.043913  0.197814                0     0        0    0
#
#            ID  len_df  class
# 0  a171e61840    7400      0
# 1  a171e61840    7400      0
# 2  a171e61840    7400      0
# 3  a171e61840    7400      0
# 4  a171e61840    7400      0

# %%
df.describe()
# Out:
#                Time          AccV         AccML         AccAP  \
# count  7.062672e+06  7.062672e+06  7.062672e+06  7.062672e+06
# mean   9.289467e+03 -9.306317e+00 -2.012513e-01  1.808524e+00
# std    1.399893e+04  1.080174e+00  1.269525e+00  2.285849e+00
# min    0.000000e+00 -3.552112e+01 -2.616440e+01 -4.782964e+01
# 25%    2.119000e+03 -9.762402e+00 -9.295446e-01  5.672254e-01
# 50%    4.310000e+03 -9.363524e+00 -1.722245e-01  1.987101e+00
# 75%    8.433000e+03 -8.776814e+00  5.752114e-01  3.449026e+00
# max    9.707600e+04  2.090695e+01  2.748472e+01  3.033769e+01
#
#        StartHesitation          Turn       Walking           idx  \
# count     7.062672e+06  7.062672e+06  7.062672e+06  7.062672e+06
# mean      4.315506e-02  2.376979e-01  2.942767e-02  4.045698e+02
# std       2.032061e-01  4.256731e-01  1.690020e-01  2.390319e+02
# min       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%       0.000000e+00  0.000000e+00  0.000000e+00  1.920000e+02
# ...

# %%
df[['AccV', 'AccML', 'AccAP']] = df[['AccV', 'AccML', 'AccAP']]/9.8

# %%
df['ID'].unique()
# Out:
# array(['a171e61840', '4171ea3a0c', '0f985a8440', '5d320ade20',
#        'ae8c67086b', 'b7214cbf21', 'e18fcafee8', '79568b8e25',
#        'feba449e1a', '7ebad45aec', 'd9bf33ecd9', 'b72fcfad61',
#        '5ff654941a', '98c313f19c', '0ee65f094c', '7fb91164ad',
#        'ea3885ab66', '053e7a7261', '9d161e0027', 'f5649e13d9',
#        '09575b5dae', 'ffda8fadfd', 'd30bf7abc2', '685a08f19d',
#        '4833cbd13b', '12dd57ee9c', 'bdbff4f3a0', '3c72bc1e83',
#        'f1973987d9', 'b109fba6f4', '066f785ce0', '0383be6b43',
#        '263f86b1d5', '67c9018b72', '7d6a7ad9ec', 'be08d9c1a3',
#        'ca17b5a4f1', '550185d2ac', 'f017f06087', 'ca88d0aa81',
#        '3c695f53c3', '2365c918c9', '54d1f4eece', 'e42ab4e307',
#        'b19eb6e513', '67624d0d1c', 'e5d573a30f', 'cbc907dd0e',
#        '01d0fe7266', '95f48f9ff5', 'f8fcc402db', '8229541018',
#        '7a01af7b19', '439f6c74ef', 'd2382704e0', '94305d2147',
#        '15671a03ca', 'd78c6c78c6', '1c9f1bb280', '5a321dde31',
# ...

# %%
df[df['StartHesitation']==1]['ID'].unique()
# Out:
# array(['7fb91164ad', '2365c918c9', 'b19eb6e513', 'a68f95a17d',
#        '9b378f315c', '9131b68d1e', '9a7a5e1df2', 'e318182fe2',
#        'eaa4651a87', 'f60bf42bd8', 'b670d1cddd', 'ec5273b4b5',
#        'a9332a5f96', '76c7edf878', 'e13d9996ad', '19fa6cec5a',
#        '8c149c4de4', 'dec1b7c109', '692e9e05ef', 'bc75d248da',
#        'babcb58d97', '51c15f0850', '2ea063ca4f', 'c49fe646a1',
#        'c68009f93d', 'bc4a075d9b', 'f00d8c57fa', '3ba3590a08',
#        'd675e28c20', 'c23e55e654', 'be2740b333', '8969714d63',
#        'e3406f028b', '59e051f322', 'd447a6566e', 'b501fddd5a',
#        '94d4aedadb', 'e7b5afe544', 'be8fdfa712', 'ae4d837055',
#        'eac0169d51', '5524e00b0c', 'c8622e0019', 'ff4f844fd3',
#        'c36c3860e7', 'd98358a75f', 'd9576be6e3', '2d4c5f6c17',
#        '71bc892dd5', 'cd7bca4654', '8126370646', '6845feb630',
#        'b62d30cabd', '35bd42e628', '150e8227fc', '714dc454eb',
#        '9e6056e271', '91ffb7843c', '9d6017c17e', 'bfe8fee128',
# ...

# %%
tmp = df[df['ID']=='a171e61840']
fig,ax=plt.subplots(2,1,figsize=(20,10),sharex = True)
ax[0].plot(tmp[['AccV']], label = 'AccV')
ax[0].plot(tmp[['AccML']]+.5, label = 'AccML')
ax[0].plot(tmp[['AccAP']]+1.5, label = 'AccAP')
ax[0].legend()
ax[1].plot(tmp[['StartHesitation']]*1.2, label = 'StartHesitation')
ax[1].plot(tmp[['Turn']]*.8, label = 'Turn')
ax[1].plot(tmp[['Walking']], label = 'Walking')
ax[1].legend()

# %%
tmp = df[df['ID']=='e7b5afe544']
fig,ax=plt.subplots(2,1,figsize=(20,10), sharex = True)
ax[0].plot(tmp[['AccV']], label = 'AccV')
ax[0].plot(tmp[['AccML']]+.5, label = 'AccML')
ax[0].plot(tmp[['AccAP']]+1.5, label = 'AccAP')
ax[0].legend()
ax[1].plot(tmp[['StartHesitation']]*1.2, label = 'StartHesitation')
ax[1].plot(tmp[['Turn']]*.8, label = 'Turn')
ax[1].plot(tmp[['Walking']], label = 'Walking')
ax[1].legend()

# %%
tmp = df[df['ID']=='e7b5afe544'][1000:2000]
fig,ax=plt.subplots(2,1,figsize=(20,10), sharex = True)
ax[0].plot(tmp[['AccV']], label = 'AccV')
ax[0].plot(tmp[['AccML']]+.5, label = 'AccML')
ax[0].plot(tmp[['AccAP']]+1.5, label = 'AccAP')
ax[0].legend()
ax[1].plot(tmp[['StartHesitation']]*1.2, label = 'StartHesitation')
ax[1].plot(tmp[['Turn']]*.8, label = 'Turn')
ax[1].plot(tmp[['Walking']], label = 'Walking')
ax[1].legend()

# %%
import seaborn as sns

# calculate the correlation matrix on the numeric columns
corr = df[['Time', 'AccV', 'AccML', 'AccAP', 'StartHesitation', 'Turn', 'Walking','normal', 'fog']].select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 4
#       1 import seaborn as sns
#       3 # calculate the correlation matrix on the numeric columns
# ----> 4 corr = df[['Time', 'AccV', 'AccML', 'AccAP', 'StartHesitation', 'Turn', 'Walking','normal', 'fog']].select_dtypes('number').corr()
#       6 # plot the heatmap
#       7 sns.heatmap(corr)
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
df.columns
# Out:
# Index(['Time', 'AccV', 'AccML', 'AccAP', 'StartHesitation', 'Turn', 'Walking',
#        'idx', 'ID', 'len_df', 'class', 'normal', 'fog'],
#       dtype='object')

# %%
df[['normal', 'fog']] = pd.get_dummies(df['class'], prefix='class')

# %%
to_hist = [ ['StartHesitation' ,int(df[['StartHesitation']].sum())],
            ['Turn', int(df[['Turn']].sum())],
            ['Walking', int(df[['Walking']].sum())],
            ['normal', int(df[['normal']].sum())]]

# %%
plt.hist(df[['StartHesitation']][df[['StartHesitation']]==1],label = 'StartHesitation')
plt.hist(df[['Turn']][df[['Turn']]==1]*1.25,label ='Turn')
plt.hist(df[['Walking']][df[['Walking']]==1]*1.5,label ='Walking')
plt.hist(df[['normal']][df[['normal']]==1]*1.75,label ='normal')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 4
#       2 plt.hist(df[['Turn']][df[['Turn']]==1]*1.25,label ='Turn')
#       3 plt.hist(df[['Walking']][df[['Walking']]==1]*1.5,label ='Walking')
# ----> 4 plt.hist(df[['normal']][df[['normal']]==1]*1.75,label ='normal')
#       5 plt.legend()
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
# ...

# %%
df_subjects = pd.read_csv('D:\\Career\\GradProj\\New deal\\Dataset\\subjects.csv')

# %%
df_subjects.head()
# Out:
#    Unnamed: 0 Subject  Visit  Age Sex  YearsSinceDx  UPDRSIII_On  \
# 0           0  00f674    2.0   63   M          27.0         43.0
# 1           1  00f674    1.0   63   M          27.0         31.0
# 2           2  02bc69    NaN   69   M           4.0         21.0
# 3           3  040587    2.0   75   M          26.0         52.0
# 4           4  040587    1.0   75   M          26.0         47.0
#
#    UPDRSIII_Off  NFOGQ
# 0          49.0     24
# 1          30.0     26
# 2           NaN     22
# 3          69.0     21
# 4          75.0     24

# %%
df_subjects.describe()
# Out:
#        Unnamed: 0       Visit         Age  YearsSinceDx  UPDRSIII_On  \
# count  173.000000  111.000000  173.000000    173.000000   172.000000
# mean    86.000000    1.369369   67.763006     10.383931    34.273256
# std     50.084928    0.484823    7.972075      6.289191    12.732552
# min      0.000000    1.000000   28.000000      0.420000     5.000000
# 25%     43.000000    1.000000   62.000000      6.000000    25.000000
# 50%     86.000000    1.000000   68.000000      9.000000    35.000000
# 75%    129.000000    2.000000   73.000000     15.000000    42.250000
# max    172.000000    2.000000   94.000000     30.000000    79.000000
#
#        UPDRSIII_Off       NFOGQ
# count    132.000000  173.000000
# mean      42.878788   17.121387
# std       12.998550    7.575377
# min       15.000000    0.000000
# 25%       33.000000   15.000000
# 50%       43.000000   19.000000
# 75%       49.250000   22.000000
# max       91.000000   29.000000

# %%
plt.hist(df_subjects[['Age']])
plt.text(60,-5, 'age', horizontalalignment='center',verticalalignment='center')
# Out:
# Text(60, -5, 'age')

# %%
from mpl_toolkits import mplot3d
from matplotlib.pyplot import figure

# %%
fig1=plt.figure(figsize=(30,30))
ax=fig1.add_subplot(211,projection='3d')

xdata = np.array((.25))
ydata = np.array((3))
zdata = np.array((6))
ax.set_xlabel('Best time window')
ax.set_ylabel('Models')
ax.set_zlabel('Z')
ax.set_yticklabels(['Model 1','Model 2','Model 3','Model 4','Model 5'])
ax.set_zticklabels(['Channel 1','Channel 2','Channel 3','Channel 1,2','Channel 1,3','Channel 2,3'])
plt.xlim([0,2])
plt.ylim([0,5])
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='rainbow',s = 1000);
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_9172\3914781809.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Model 1','Model 2','Model 3','Model 4','Model 5'])
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_9172\3914781809.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_zticklabels(['Channel 1','Channel 2','Channel 3','Channel 1,2','Channel 1,3','Channel 2,3'])

# %%
fig1=plt.figure(figsize=(20,5))
ax=fig1.add_subplot(211)

# ax.scatter([-10],[0], cmap='rainbow',s = 1000)
ax.bar([1],[.8])
ax.bar([2],[.7])
ax.bar([3],[.5])
ax.bar([4],[.9])
ax.bar([0],[.6])
ax.set_xticklabels(['','Model 1','Model 2','Model 3','Model 4','Model 5'])
ax.set_ylabel('accuracy ')
plt.ylim([.3,1])
plt.xlim([-1,5])
#ax.get_yaxis().set_visible(False)
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_9172\414605147.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['','Model 1','Model 2','Model 3','Model 4','Model 5'])
# (-1.0, 5.0)

# %%
df_subjects[['female','male']] = pd.get_dummies(df_subjects['Sex'])

# %%
df_subjects.head()
# Out:
#    Unnamed: 0 Subject  Visit  Age Sex  YearsSinceDx  UPDRSIII_On  \
# 0           0  00f674    2.0   63   M          27.0         43.0
# 1           1  00f674    1.0   63   M          27.0         31.0
# 2           2  02bc69    NaN   69   M           4.0         21.0
# 3           3  040587    2.0   75   M          26.0         52.0
# 4           4  040587    1.0   75   M          26.0         47.0
#
#    UPDRSIII_Off  NFOGQ  male  female
# 0          49.0     24     1       0
# 1          30.0     26     1       0
# 2           NaN     22     1       0
# 3          69.0     21     1       0
# 4          75.0     24     1       0

# %%
plt.hist(df_subjects[['male']][df_subjects[['male']]==1],label = 'male')
plt.hist(df_subjects[['female']][df_subjects[['female']]==1]*1.2,label = 'female')
plt.legend()
